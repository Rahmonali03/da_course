# %% [markdown]
# # Независимые события и условная вероятность

# %% [markdown]
# ## Независимые и зависимые события

# %% [markdown]
# ### Независимые события

# %% [markdown]
# > <u>События $A$ и $B$ называются независимыми</u>, если факт наступления одного из них никак не влияет на вероятность наступления другого.
#
# *Пример*. Бросок монеты и игрального кубика.
# 1. Событие $A$: выпала решка на монете ($P(A)=0.5$).
# 2. Событие $B$: выпала шестёрка на кубике ($P(B)=\frac{1}{6}$).
#
# Эти события независимы, так как результат броска монеты не влияет на результат броска кубика.

# %% [markdown]
# ### Зависимые события

# %% [markdown]
# > <u>События $A$ и $B$ называются зависимыми</u>, если вероятность одного события изменяется в зависимости от наступления другого.
#
# *Пример*. Выбор шаров из мешка, без возврата. В мешке 5 белых и 3 чёрных шара.
# 1. Событие $A$: первый шар белый ($P(A)=\frac{5}{8}$).
# 2. Событие $B$: второй шар белый. Так как из мешка уже был вытащен один белый шар, количество как желаемых так и возможных исходов изменилось. Теперь в мешке осталось не 5 а 4 белых шара, а общее количество шаров теперь 7. Следовательно, вероятность получить ещё один белый шар $\frac{4}{7}$.

# %% [markdown]
# ---
#
# ❓Задача
# Определите которые из приведённых событий являются независимыми либо зависимыми:
# * пошёл дождь и вы промокли | <input type="checkbox"> *независимые* <input type="checkbox"> *зависимые*
# * в рулетке два раза подряд выпало 20 чёрное | <input type="checkbox"> *независимые* <input type="checkbox"> *зависимые*
# * вы не подали милостыню и у вас сломалась машина | <input type="checkbox"> *независимые* <input type="checkbox"> *зависимые*
# * вы улучшили дизайн продукции и количество продаж увеличилось | <input type="checkbox"> *независимые* <input type="checkbox"> *зависимые*

# %% [markdown]
# ## Общая формула умножения

# %% [markdown]
# **Общая формула умножения** - для любых двух событий $A$ и $B$: $$P(A \cap B)=P(A) \cdot P(B|A)$$ где:
# * $P(A)$ - вероятность наступления события $A$,
# * $P(B|A)$ - вероятность наступления события $B$, при условии что наступило событие $A$.

# %% [markdown]
# ---
#
# >Общее правило сложения: $P(A \cup B)=P(A)+P(B)-P(A \cap B)$
# >Общее правило умножения: $P(A \cap B)=P(A) \cdot P(B|A)$
#
# ---

# %% [markdown]
# **Пример**
# В таблице ниже приводится результат опроса студентов на предмет того умеют ли они водить машину.

# %% [markdown]
# |             | Умеет водить (D) | Не умеет водить (D') | Всего   |
# |-------------|------------------|----------------------|---------|
# | Девушка (F) | 36               | 144                  | **180** |
# | Парень  (M) | 288              | 32                   | **320** |
# | **Всего**   | **324**          | **176**              | **500** |

# %% [markdown]
# Допустим, что мы рандомно выбираем из этой группы одного студента. Постараемся найти ответы на следующие вопросы:
#
# a) какова вероятность, что этот студент умеет водить? Всего у нас 500 студентов, 324 из которых умеют водить. Следовательно, $P(D)=\frac{324}{500}=.648$
#
# b) какова вероятность, что этот студент парень? Всего в группе 320 парней, а значит $P(M)=\frac{320}{500}=.64$
#
# c) какова вероятность, что этот студент парень и он умеет водить? 288 парней умеют водить, таким образом $P(M \cap D)=\frac{288}{500}=.576$
#
# d) какова вероятность того, что этот студент умеет водить, при условии что он парень? Всего парней 320, из которых 288 умеет водить. Следовательно, $P(D|M)=\frac{288}{320}=.9$

# %% [markdown]
# А теперь представим, что нам даны лишь вероятность события $P(M)$ и $P(D|M)$ и нам нужно рассчитать вероятность $P(M \cap D)$. Используя общую формулу умножения получаем:
#
# $$P(M \cap D) = P(M) \cdot P(D|M)=.64 \cdot .9 = .576$$
# Мы получили тот же результат, что и при ответе на вопрос **c)**, но имея только вероятности двух других событий.

# %% [markdown]
# ## Условная вероятность

# %% [markdown]
# Переставив местами элементы общей формулы умножения мы получим формулу условной вероятности:
#
# $$P(B|A)=\frac{P(A \cap B)}{P(A)}$$

# %% [markdown]
# 💡Обратите внимание, что в деноминаторе всегда стоит вероятность события "при условии".

# %% [markdown]
# Условная вероятность используется когда два и более событий не являются независимыми. Это означает что на вероятность одного события влияет то, произошло ли другое событие.

# %% [markdown]
# ---
# ❓Задача
# Клинические исследования одного антидепрессанта показали, что при употреблении данного препарата имеется 14% вероятности побочного эффекта в виде бессонницы (I), 26% вероятности побочного эффекта в виде головных болей (H), и 5% вероятности обоих побочных эффектов (I and H).
#
# * Предположим, что пациент принимавший этот препарат испытывает бессонницу. Какова вероятность того, что он также будет испытывать головные боли?
#
# * Предположим, что препарат вызывает у пациента головные боли. Какова вероятность того, что он также будет вызывать бессонницу?

# %%
p_insomnia = .14
p_headache = .26
p_insomnia_and_headache = .05

p_headache_given_insomnia = p_insomnia_and_headache / p_insomnia
p_insomnia_given_headache = p_insomnia_and_headache / p_headache

print(f"вероятность головной боли при условии бессонницы: {round(p_headache_given_insomnia,2)}")
print(f"вероятность бессонницы при условии головной боли: {round(p_insomnia_given_headache, 2)}")
# Out:
# вероятность головной боли при условии бессонницы: 0.36
# вероятность бессонницы при условии головной боли: 0.19

# %% [markdown]
# ## Нахождение условной вероятности табличным способом

# %% [markdown]
# Теперь попробуем найти ответ на следующий вопрос: если препарат вызывает у пациента бессонницу, какова вероятность что он не будет испытывать головные боли?
#
# Нахождение ответа на такой вопрос задача нетривиальная. Один из способов, который мы можем для этого использовать - табличный способ.
#
# Прежде всего, вспомним какие у нас есть исходные данные:
# * $P(I)=.14$
# * $P(H)=.26$
# * $P(I \cap H)=.05$

# %% [markdown]
# Используя эти исходные данные, построим следующую таблицу:
#
# |           | I         | not_I | **total** |
# |-----------|-----------|-------|-----------|
# | H         | .05       |       | **.26**   |
# | not_H     |           |       |           |
# | **total** | **.14**   |       | **1**     |

# %% [markdown]
# Так как в последнем столбце и в последней строке у нас находятся итоги, простыми операциями вычитания мы можем заполнить пустые ячейки. В результате мы получим как вероятности каждого отдельного события так и вероятности того что они произойдут вместе.
#
# |           | I         | not_I   | **total** |
# |-----------|-----------|---------|-----------|
# | H         | .05       | .21     | **.26**   |
# | not_H     | .09       | .65     | **.74**   |
# | **total** | **.14**   | **.86** | **1**     |

# %% [markdown]
# Используя заполненную таблицу вероятностей, ответим на следующие вопросы:
#
# a) если препарат вызывает у пациента бессонницу, какова вероятность что он не будет испытывать головные боли?
# $$P(H'|I)=\frac{P(I \cap H')}{P(I)}=\frac{.09}{.14}≈.64$$
#
# b) если препарат вызывает у пациента головные боли, какова вероятность что он не будет испытывать бессонницу?
# $$P(I'|H)=\frac{P(H \cap I')}{P(H)}=\frac{.21}{.26}≈.81$$

# %% [markdown]
# ---
# ❓Задача
# Определите следующие вероятности:
# a) если препарат не вызывает у пациента бессонницу, какова вероятность что он будет испытывать головные боли?
# b) если препарат не вызывает у пациента головные боли, какова вероятность что он также не будет вызывать бессонницу?

# %%
p_insomnia = .14
p_headache = .26
p_insomnia_and_headache = .05

p_headache_and_not_insomnia = p_headache - p_insomnia_and_headache
# print(p_headache_and_not_insomnia)

p_not_insomnia = 1 - p_insomnia
p_headache_given_not_insomnia = p_headache_and_not_insomnia / p_not_insomnia

p_not_insomnia_and_not_headache = p_not_insomnia - p_headache_and_not_insomnia
p_not_insomnia_given_not_headache = p_not_insomnia_and_not_headache / p_not_headache

print(p_headache_given_not_insomnia)
print(p_not_insomnia_given_not_headache)
# Out:
# 0.24418604651162792
# 0.8783783783783783

# %% [markdown]
# >💡 Обратите внимание что $P(H|I)=1-P(H'|I)$. Т.е. закон комплементарности применим и к условным вероятностям.

# %% [markdown]
# >❗ Но $P(H|I)\not=1-P(H|I')$. Т.е. закон комплементарности применим к условным вероятностям, ***только если*** они относятся к одному условию.

# %% [markdown]
# ---
#
# ❓Задача
# Нам известны следующие вероятности:
# * $P(B)=.4$
# * $P(D)=.95$
# * $P(B \cap D)=.38$
#
# На основе указанных вероятностей определите являются ли события B и D зависимыми.

# %% [markdown]
# $P(A \cap B)=P(A) \cdot P(B)$
# $P(A \cap B)=P(A) \cdot P(B|A)$

# %%
p_b = .4
p_d = .95
p_b_and_d = .38

p_b_given_d = p_b_and_d / p_d
p_b_given_d == p_b
# Out:
# True

# %% [markdown]
# ## Дерево вероятностей

# %% [markdown]
# Второй метод нахождения вероятности событий это `дерево вероятностей`.

# %% [markdown]
# **Пример**
# Торговый представитель сообщает своему другу, что вероятность того что он заключит важный контракт составляет 40%. Если контракт будет заключён, он получит большие премиальные и с вероятностью 90% поедет в отпуск в Дубай. Даже если контракт не удастся заключить он всё равно планирует провести отпуск в Дубае, но уже с вероятностью 30%.
#
# Используя данную информацию попробуем построить дерево вероятностей.
#
# Первый уровень дерева состоит из двух веток. В каждом последующем уровне дерева из веток предыдущих уровней выводится пара новых веток.
#
# Первый уровень нашего дерева будет связан с контрактом. Нам нужно построить две ветки - ветка вероятности заключения контракта ($P(C)$) и ветка вероятности не заключения контракта ($P(C')$). Мы знаем $P(C)$, следовательно можем вычислить его комплемент:
# * $P(C)=.4$
# * $P(C')=1-P(C)=.6$
#
# Получаем первый уровень дерева:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Теперь, для каждой ветки первого уровня нам нужно построить ветки следующих вероятностей:
# * вероятность отпуска при условии заключения контракта $P(V|C)=.9$
# * вероятность отмены отпуска при условии заключения контракта $P(V'|C)=1-P(V|C)=1-.9=.1$
#
# * вероятность отпуска при условии что контракт не будет заключен $P(V|C')=.3$
# * вероятность отмены отпуска при условии что контракт не будет заключен $P(V'|C')=1-P(V|C')=1-.3=.7$
#
# Используя полученные вероятности, строим второй уровень дерева:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 💡 На первом уровне дерева находятся вероятности причины, в то время как на следующих уровнях размещаются вероятности следствия (условные вероятности).

# %% [markdown]
# 💡 Сумма вероятностей каждой рогатки (парных веток) равна 1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Формула полной вероятности

# %% [markdown]
# Имея готовое дерево вероятностей, попробуем найти ответ на следующий вопрос: *какова вероятность того, что торговый представитель поедет в отпуск?*

# %% [markdown]
# У нас есть два сценария:
# * торговый представитель заключает контракт **и** едет в отпуск
# * **или** торговый представитель не заключает контракт **и** едет в отпуск

# %% [markdown]
# Следовательно: $P(V)=P(C \cap V) + P(C' \cap V)$

# %% [markdown]
# Используя дерево считаем:
# * $P(C \cap V)=P(C) \cdot P(V|C)=.4 \cdot .9=.36$
# * $P(C' \cap V)=P(C') \cdot P(V|C')=.6 \cdot .3=.18$
#
# Таким образом:
# * $P(V)=P(C \cap V)+P(C' \cap V)=.36+.18=.54$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Формула которую мы получили при нахождении вероятности поездки в отпуск, называется формулой полной вероятности.
# **Формула полной вероятности** - позволяет вычислить вероятность интересующего события через условные вероятности этого события.
# $$P(B)=P(A) \cdot P(B|A)+P(A') \cdot P(B|A')$$

# %% [markdown]
# ## Формула Байеса

# %% [markdown]
# Теперь, допустим что торговый представитель поехал в отпуск. Учитывая этот факт, какова вероятность того, что ему удалось подписать контракт?

# %% [markdown]
# Зная общую формулу умножения, мы можем вычислить эту вероятность с помощью следующего равенства: $P(C|V)=\frac{P(C \cap V)}{P(V)}$

# %% [markdown]
# Мы знаем, что вероятность подписания контракта и поездки в отпуск можно вычислить так: $P(C \cap V)=P(C) \cdot P(V|C)$

# %% [markdown]
# Подставив это равенство вместо $P(C \cap V)$ получаем: $P(C|V)=\frac{P(C \cap V)}{P(V)}=\frac{P(C) \cdot P(V|C)}{P(V)}=\frac{.4 \cdot .9
# }{.54}=\frac{.36}{.54}≈.67$

# %% [markdown]
# Формула, которую мы получили называется формулой Байеса.

# %% [markdown]
# **Формула (теорема) Байеса** позволяет рассчитать вероятность события если следствие и причину поменять местами. Т.е. по известному факту события вычислить вероятность того, что оно было вызвано данной причиной.

# %% [markdown]
# $$P(A|B)=\frac{P(A) \cdot P(B|A)}{P(B)}$$

# %% [markdown]
# ---
#
# ❓Задача
# В 2002 году Национальный Исследовательский Совет США, решил выяснить насколько точными являются показания детектора лжи. Выяснилось, что детекторы лжи в 80% случаев приводят к заключению о том что испытуемый шпион, при условии что он действительно является шпионом. Но в 16% случаев результаты детектора приводят к такому заключению, когда испытуемый не является шпионом.
# Представим, что в некоей компании 1 из 1000 сотрудников занимаются промышленным шпионажем в пользу конкурентов. Зная это, ответьте на следующие вопросы:
# * какова вероятность что рандомный сотрудник компании не является шпионом и это подтверждается детектором?
# * какова вероятность что рандомный сотрудник компании является шпионом и детектор этого не обнаруживает?
# * если детектор указывает на то что сотрудник шпион, какова вероятность что он действительно является шпионом?

# %% [markdown]
# ---
#
# ❓Задача
# Известно что движок некоей модели автомобиля перегревается в 3% случаев. При перегреве движка, в 98% случаев включается индикатор оповещения. Однако, в 1% случаев, индикатор включается без перегрева. Ответьте на следующие вопросы:
# * какова вероятность включения индикатора?
# * если водитель видит включённый индикатор, какова вероятность того что движок действительно перегрелся?
